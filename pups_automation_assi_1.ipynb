# %%
import requests

def google_search_autocomplete(query, api_key):
    url = "https://www.googleapis.com/customsearch/v1"
    params = {
        'q': query,
        'key': api_key,
        'cx': '57aed0bf336ad434f'
    }

    response = requests.get(url, params=params)
    data = response.json()

    if 'items' in data:
        return [item['title'] for item in data['items']]
    else:
        return []

def main():
    api_key = "AIzaSyBgkgGHh1_GJ_OGLsj3Xd_Urxwyw4scaEo"
    search_query = "Dhaka"

    autocomplete_results = google_search_autocomplete(search_query, api_key)

    if autocomplete_results:
        shortest = min(autocomplete_results, key=len)
        longest = max(autocomplete_results, key=len)

        print(f"Shortest Autocomplete: {shortest}")
        print(f"Longest Autocomplete: {longest}")
    else:
        print("No autocomplete results found.")

if __name__ == "__main__":
    main()
# Out:
# Shortest Autocomplete: Dhaka - Wikipedia
# Longest Autocomplete: Premium wellness hotel in Gulshan 2 | The Westin Dhaka | Marriott ...

# %%
import pandas as pd
import requests

# Define the list of sheet names
sheet_names = ["Saturday", "Sunday", "Monday", "Tuesday", "Wednesday", "Thursday", "Friday"]

# Create an empty dictionary to store DataFrames for each sheet
dfs = {}

# Read data from each sheet and store it in the dictionary
excel_file_path = '/content/Excel.xlsx'  # Replace with the actual path to your Excel file
for sheet_name in sheet_names:
    df = pd.read_excel(excel_file_path, sheet_name=sheet_name)
    dfs[sheet_name] = df

# Reset any custom display options to their default values if needed
pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')

def google_search_autocomplete(query, api_key):
    url = "https://www.googleapis.com/customsearch/v1"
    params = {
        'q': query,
        'key': api_key,
        'cx': '57aed0bf336ad434f'
    }

    response = requests.get(url, params=params)
    data = response.json()

    if 'items' in data:
        return [item['title'] for item in data['items']]
    else:
        return []

def main():
    api_key = "AIzaSyBgkgGHh1_GJ_OGLsj3Xd_Urxwyw4scaEo"

    for sheet_name, df in dfs.items():
        if "Unnamed: 2" in df.columns:
            queries = df["Unnamed: 2"].dropna().unique()
            for query in queries:
                autocomplete_results = google_search_autocomplete(query, api_key)

                if autocomplete_results:
                    shortest = min(autocomplete_results, key=len)
                    longest = max(autocomplete_results, key=len)

                    # Update the DataFrame with the results
                    df.loc[df["Unnamed: 2"] == query, "Unnamed: 3"] = longest
                    df.loc[df["Unnamed: 2"] == query, "Unnamed: 4"] = shortest

    # Display the updated data from each sheet
    for sheet_name, df in dfs.items():
        print(f"Sheet: {sheet_name}")
        print(df)  # Display the entire DataFrame

if __name__ == "__main__":
    main()
# Out:
# Sheet: Saturday
#     Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0          NaN        NaN        NaN
# 1          NaN   Keyword1      Dhaka
# 2          NaN   Keyword2   Saturday
# 3          NaN   Keyword3       Baby
# 4          NaN   Keyword4     School
# 5          NaN   Keyword5    Cricket
# 6          NaN   Keyword6      Momey
# 7          NaN   Keyword7        Int
# 8          NaN   Keyword8       Look
# 9          NaN   Keyword9      Hello
# 10         NaN  Keyword10         By
#
#                                            Unnamed: 3  \
# 0                                      Longest Option
# 1   Premium wellness hotel in Gulshan 2 | The West...
# 2   Shop Small with American Express | Support Sma...
# 3   Clean Bandit - Baby (feat. Marina & Luis Fonsi...
# 4   School of the Art Institute of Chicago - Best ...
# 5   Cricket | Definition, Origin, History, Equipme...
# 6   High-throughput monitoring of major cell funct...
# 7    Built-in Functions — Python 3.11.5 documentation
# 8   About this Collection | Look Collection | Digi...
# 9   hello | naturally friendly products, vegan + n...
# 10  Pay Your Taxes by Debit or Credit Card or Digi...
#
#                    Unnamed: 4
# 0            Shortest\nOption
# 1           Dhaka - Wikipedia
# 2        Saturday - Wikipedia
# 3              — Buy Buy Baby
# 4          School - Wikipedia
# 5               Cricket Media
# 6    Momey - Urban Dictionary
# 7                    nato.int
# 8                Look Cinemas
# 9                    no hello
# 10  Renew my Passport by Mail
# Sheet: Sunday
#     Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0          NaN        NaN        NaN
# 1          NaN   Keyword1      Dhaka
# 2          NaN   Keyword2     Sunday
# 3          NaN   Keyword3       Baby
# 4          NaN   Keyword4     School
# 5          NaN   Keyword5    Cricket
# 6          NaN   Keyword6      Momey
# 7          NaN   Keyword7        Int
# 8          NaN   Keyword8       Look
# 9          NaN   Keyword9      Hello
# 10         NaN  Keyword10         By
#
#                                            Unnamed: 3  \
# 0                                      Longest Option
# 1   Premium wellness hotel in Gulshan 2 | The West...
# 2   Your Happy Place - Sunday River offers the mos...
# 3   Clean Bandit - Baby (feat. Marina & Luis Fonsi...
# 4   School of the Art Institute of Chicago - Best ...
# 5   Cricket | Definition, Origin, History, Equipme...
# 6   High-throughput monitoring of major cell funct...
# 7    Built-in Functions — Python 3.11.5 documentation
# 8   About this Collection | Look Collection | Digi...
# 9   hello | naturally friendly products, vegan + n...
# 10  Pay Your Taxes by Debit or Credit Card or Digi...
#
#                    Unnamed: 4
# 0            Shortest\nOption
# 1           Dhaka - Wikipedia
# 2                Sunday Bikes
# 3              — Buy Buy Baby
# 4          School - Wikipedia
# 5               Cricket Media
# 6    Momey - Urban Dictionary
# 7                    nato.int
# 8                Look Cinemas
# 9                    no hello
# 10  Renew my Passport by Mail
# Sheet: Monday
#     Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0          NaN        NaN        NaN
# 1          NaN   Keyword1      Dhaka
# 2          NaN   Keyword2      Dates
# 3          NaN   Keyword3       Baby
# 4          NaN   Keyword4     School
# 5          NaN   Keyword5    Cricket
# 6          NaN   Keyword6      Momey
# 7          NaN   Keyword7        Int
# 8          NaN   Keyword8       Look
# 9          NaN   Keyword9      Hello
# 10         NaN  Keyword10         By
#
#                                            Unnamed: 3  \
# 0                                      Longest Option
# 1   Premium wellness hotel in Gulshan 2 | The West...
# 2   LSAT Dates, Deadlines, and Score Release Dates...
# 3   Clean Bandit - Baby (feat. Marina & Luis Fonsi...
# 4   School of the Art Institute of Chicago - Best ...
# 5   Cricket | Definition, Origin, History, Equipme...
# 6   High-throughput monitoring of major cell funct...
# 7    Built-in Functions — Python 3.11.5 documentation
# 8   About this Collection | Look Collection | Digi...
# 9   hello | naturally friendly products, vegan + n...
# 10  Pay Your Taxes by Debit or Credit Card or Digi...
#
#                    Unnamed: 4
# 0            Shortest\nOption
# 1           Dhaka - Wikipedia
# 2           The Visa Bulletin
# 3              — Buy Buy Baby
# 4          School - Wikipedia
# 5               Cricket Media
# 6    Momey - Urban Dictionary
# 7                    nato.int
# 8                Look Cinemas
# 9                    no hello
# 10  Renew my Passport by Mail
# Sheet: Tuesday
#     Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0          NaN        NaN        NaN
# 1          NaN   Keyword1      Dhaka
# 2          NaN   Keyword2   Saturday
# 3          NaN   Keyword3       Baby
# 4          NaN   Keyword4     School
# 5          NaN   Keyword5    Cricket
# 6          NaN   Keyword6      Momey
# 7          NaN   Keyword7        Int
# 8          NaN   Keyword8      Hubby
# 9          NaN   Keyword9      Hello
# 10         NaN  Keyword10         By
#
#                                            Unnamed: 3  \
# 0                                      Longest Option
# 1   Premium wellness hotel in Gulshan 2 | The West...
# 2   Shop Small with American Express | Support Sma...
# 3   Clean Bandit - Baby (feat. Marina & Luis Fonsi...
# 4   School of the Art Institute of Chicago - Best ...
# 5   Cricket | Definition, Origin, History, Equipme...
# 6   High-throughput monitoring of major cell funct...
# 7    Built-in Functions — Python 3.11.5 documentation
# 8   Peanut Butter-Pretzel Truffles | Chubby Hubby ...
# 9   hello | naturally friendly products, vegan + n...
# 10  Pay Your Taxes by Debit or Credit Card or Digi...
#
#                    Unnamed: 4
# 0            Shortest\nOption
# 1           Dhaka - Wikipedia
# 2        Saturday - Wikipedia
# 3              — Buy Buy Baby
# 4          School - Wikipedia
# 5               Cricket Media
# 6    Momey - Urban Dictionary
# 7                    nato.int
# 8               Hubby Jenkins
# 9                    no hello
# 10  Renew my Passport by Mail
# Sheet: Wednesday
#     Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0          NaN        NaN        NaN
# 1          NaN   Keyword1      Dhaka
# 2          NaN   Keyword2   Saturday
# 3          NaN   Keyword3       Baby
# 4          NaN   Keyword4     School
# 5          NaN   Keyword5    Cricket
# 6          NaN   Keyword6     Pathao
# 7          NaN   Keyword7        Int
# 8          NaN   Keyword8       Look
# 9          NaN   Keyword9      Hello
# 10         NaN  Keyword10         By
#
#                                            Unnamed: 3  \
# 0                                      Longest Option
# 1   Premium wellness hotel in Gulshan 2 | The West...
# 2   Shop Small with American Express | Support Sma...
# 3   Clean Bandit - Baby (feat. Marina & Luis Fonsi...
# 4   School of the Art Institute of Chicago - Best ...
# 5   Cricket | Definition, Origin, History, Equipme...
# 6   Bangladesh's version of Go-Jek raises over $10...
# 7    Built-in Functions — Python 3.11.5 documentation
# 8   About this Collection | Look Collection | Digi...
# 9   hello | naturally friendly products, vegan + n...
# 10  Pay Your Taxes by Debit or Credit Card or Digi...
#
#                    Unnamed: 4
# 0            Shortest\nOption
# 1           Dhaka - Wikipedia
# 2        Saturday - Wikipedia
# 3              — Buy Buy Baby
# 4          School - Wikipedia
# 5               Cricket Media
# 6          Pathao - Wikipedia
# 7                    nato.int
# 8                Look Cinemas
# 9                    no hello
# 10  Renew my Passport by Mail
# Sheet: Thursday
#     Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0          NaN        NaN        NaN
# 1          NaN   Keyword1      Dhaka
# 2          NaN   Keyword2   Saturday
# 3          NaN   Keyword3       Baby
# 4          NaN   Keyword4     School
# 5          NaN   Keyword5    Cricket
# 6          NaN   Keyword6      Momey
# 7          NaN   Keyword7        Int
# 8          NaN   Keyword8      Goods
# 9          NaN   Keyword9      Hello
# 10         NaN  Keyword10         By
#
#                                            Unnamed: 3  \
# 0                                      Longest Option
# 1   Premium wellness hotel in Gulshan 2 | The West...
# 2   Shop Small with American Express | Support Sma...
# 3   Clean Bandit - Baby (feat. Marina & Luis Fonsi...
# 4   School of the Art Institute of Chicago - Best ...
# 5   Cricket | Definition, Origin, History, Equipme...
# 6   High-throughput monitoring of major cell funct...
# 7    Built-in Functions — Python 3.11.5 documentation
# 8   DICK'S Sporting Goods - Official Site - Every ...
# 9   hello | naturally friendly products, vegan + n...
# 10  Pay Your Taxes by Debit or Credit Card or Digi...
#
#                    Unnamed: 4
# 0            Shortest\nOption
# 1           Dhaka - Wikipedia
# 2        Saturday - Wikipedia
# 3              — Buy Buy Baby
# 4          School - Wikipedia
# 5               Cricket Media
# 6    Momey - Urban Dictionary
# 7                    nato.int
# 8           Goods - Wikipedia
# 9                    no hello
# 10  Renew my Passport by Mail
# Sheet: Friday
#     Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0          NaN        NaN        NaN
# 1          NaN   Keyword1      Dhaka
# 2          NaN   Keyword2   Saturday
# 3          NaN   Keyword3       Baby
# 4          NaN   Keyword4     School
# 5          NaN   Keyword5    Cricket
# 6          NaN   Keyword6  Geography
# 7          NaN   Keyword7        Int
# 8          NaN   Keyword8       Look
# 9          NaN   Keyword9      Hello
# 10         NaN  Keyword10         By
#
#                                            Unnamed: 3  \
# 0                                      Longest Option
# 1   Premium wellness hotel in Gulshan 2 | The West...
# 2   Shop Small with American Express | Support Sma...
# 3   Clean Bandit - Baby (feat. Marina & Luis Fonsi...
# 4   School of the Art Institute of Chicago - Best ...
# 5   Cricket | Definition, Origin, History, Equipme...
# 6   World Geography Games Online - Let's play and ...
# 7    Built-in Functions — Python 3.11.5 documentation
# 8   About this Collection | Look Collection | Digi...
# 9   hello | naturally friendly products, vegan + n...
# 10  Pay Your Taxes by Debit or Credit Card or Digi...
#
#                    Unnamed: 4
# 0            Shortest\nOption
# 1           Dhaka - Wikipedia
# 2        Saturday - Wikipedia
# 3              — Buy Buy Baby
# 4          School - Wikipedia
# 5               Cricket Media
# 6                   Geography
# 7                    nato.int
# 8                Look Cinemas
# 9                    no hello
# 10  Renew my Passport by Mail
